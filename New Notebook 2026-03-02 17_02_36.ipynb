# %%
df=spark.table("uam_2.ejercicio_clase.retail_transactions_course_dataset")

# %%
display(df)

# %% [markdown]
# Mini Lab2

# %%
df_clean = df

# %%
df_clean = df_clean.dropDuplicates(["transaction_id"])

# %%
df_clean =df_clean.dropna(subset =["transaction_id","transaction_ts","total_eur"] )

# %%
df_clean.describe

# %%
df_clean.printSchema()

# %% [markdown]
# Delta lake Versioning

# %%
df_clean.write.format("delta").mode("overwrite").saveAsTable("uam_2.ejercicio_clase.retail_delta")

# %%
# %sql
select * from uam_2.ejercicio_clase.retail_delta
