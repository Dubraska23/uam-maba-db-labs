-- %%
%python
# =========================
# Cargar tablas Gold
# =========================
df_city = spark.table("ucm.gold_city_prices")
df_trend = spark.table("ucm.gold_temporal_trends")
df_property = spark.table("ucm.gold_property_analysis")
df_district = spark.table("ucm.gold_district_analysis")
df_price_cat = spark.table("ucm.gold_price_category_analysis")
